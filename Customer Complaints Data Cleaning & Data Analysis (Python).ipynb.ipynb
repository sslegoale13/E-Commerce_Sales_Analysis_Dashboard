# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
complaints = pd.read_excel("Customer Complaints Data.xlsx")

# %%
complaints.head()
# Out:
#              Company                            Company public response  \
# 0  Cumulus Financial                                                NaN
# 1  Cumulus Financial                                                NaN
# 2  Cumulus Financial                                                NaN
# 3  Cumulus Financial  Company has responded to the consumer and the ...
# 4  Cumulus Financial                                                NaN
#
#   Company response to consumer  Complaint ID Consumer consent provided?  \
# 0      Closed with explanation       2824926       Consent not provided
# 1      Closed with explanation       1515991       Consent not provided
# 2      Closed with explanation       1145261                        NaN
# 3      Closed with explanation       2573763       Consent not provided
# 4      Closed with explanation       2573113       Consent not provided
#
#   Consumer disputed? Date Received Date Submitted  \
# 0                NaN    2018-02-24     2018-02-24
# 1                 No    2015-08-12     2015-08-12
# 2                 No    2014-12-08     2014-12-05
# 3                NaN    2017-07-13     2017-07-13
# 4                NaN    2017-07-13     2017-07-13
#
#                                  Issue                      Product State  \
# 0                 Closing your account  Credit card or prepaid card    FL
# 1  Improper contact or sharing of info              Debt Collection    CA
# 2             Deposits and withdrawals      Bank account or service    CA
# 3       Trouble during payment process                    Mortgages    CA
# 4           Struggling to pay mortgage                    Mortgages    NY
#
#                                Sub-issue  \
# 0            Company closed your account
# 1  Contacted employer after asked not to
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                   Sub-product Submitted via Tags  \
# 0  General-purpose credit card or charge card           Web  NaN
# 1                                 Credit card           Web  NaN
# 2                            Checking account      Referral  NaN
# 3                  Conventional home mortgage           Web  NaN
# 4                  Conventional home mortgage           Web  NaN
#
#   Timely response? ZIP code  Time to Receipt
# 0              Yes    33179                0
# 1              Yes    93561                0
# 2              Yes    91792                3
# 3              Yes    92629                0
# 4              Yes    10016                0
