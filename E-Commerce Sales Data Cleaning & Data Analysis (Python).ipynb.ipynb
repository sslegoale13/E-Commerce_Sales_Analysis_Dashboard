# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
orders = pd.read_excel("E-Commerce Sales Data.xlsx")

# %%
orders.head()
# Out:
#    Order Id       Date            Category Market           Region  \
# 0     61558 2017-06-17    Camping & Hiking  LATAM    South America
# 1     57472 2017-04-18    Camping & Hiking  LATAM    South America
# 2     59898 2017-05-24    Camping & Hiking  LATAM  Central America
# 3     59898 2017-05-24    Camping & Hiking  LATAM  Central America
# 4     58644 2017-06-05  Hunting & Shooting  LATAM  Central America
#
#    Customer Id   Name   Segment      City State      Country  ZIP Code  \
# 0          568   Sean  Consumer    Caguas    PR  Puerto Rico       725
# 1         3341  Carol  Consumer    Caguas    PR  Puerto Rico       725
# 2         7459   Mary  Consumer  Mayaguez    PR  Puerto Rico       680
# 3         7459   Mary  Consumer  Mayaguez    PR  Puerto Rico       680
# 4        10740   Mary  Consumer    Caguas    PR  Puerto Rico       725
#
#    Order Item Total  Quantity       Price  Profit Margin     Profit  \
# ...
